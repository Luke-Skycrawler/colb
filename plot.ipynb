# %%
import matplotlib.pyplot as plt
import numpy as np
from utils.data_collector import Profiller

# %%
prof = Profiller(max_iters = 16, frames = 50)
prof.load("output/profiler.npz")
prof.plot("convergence")
plt.show()

if True:
# if False:
    prof.load("output/baseline.npz")
    prof.plot("convergence")
    plt.show()

# %%
prof.save("output/cubic.npz")

# %%
prof.plot("alphas")
plt.show()
